# %% [markdown]
# # Actividad 1

# %%
import pandas as pd
df = pd.read_csv("../Python 3 Intermedio/dataset/Salary_Data.csv")
print(df.to_string())
# Out:
#        Age  Gender    Education Level                              Job Title  Years of Experience    Salary
# 0     32.0    Male         Bachelor's                      Software Engineer                  5.0   90000.0
# 1     28.0  Female           Master's                           Data Analyst                  3.0   65000.0
# 2     45.0    Male                PhD                         Senior Manager                 15.0  150000.0
# 3     36.0  Female         Bachelor's                        Sales Associate                  7.0   60000.0
# 4     52.0    Male           Master's                               Director                 20.0  200000.0
# 5     29.0    Male         Bachelor's                      Marketing Analyst                  2.0   55000.0
# 6     42.0  Female           Master's                        Product Manager                 12.0  120000.0
# 7     31.0    Male         Bachelor's                          Sales Manager                  4.0   80000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6699     True
# 6700     True
# 6701     True
# 6702     True
# 6703     True
# Length: 6704, dtype: bool

# %% [markdown]
# ### Edad

# %%
media_edad = df["Age"].mean()
print(media_edad)
# Out:
# 33.62085944494181

# %%
mediana_edad = df["Age"].median()
print(mediana_edad)
# Out:
# 32.0

# %%
import matplotlib as plt

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["Age"])
plt.xlabel("Edad")
plt.ylabel("Personas")
# Out:
# Text(0, 0.5, 'Personas')

# %%
max_edad = df["Age"].max()
print(max_edad)
# Out:
# 62.0

# %%
df[df["Age"]==62]
# Out:
#        Age Gender Education Level                  Job Title  \
# 1225  62.0   Male             PhD  Software Engineer Manager
# 1236  62.0   Male             PhD  Software Engineer Manager
# 1258  62.0   Male             PhD  Software Engineer Manager
# 1304  62.0   Male             PhD  Software Engineer Manager
# 1305  62.0   Male             PhD  Software Engineer Manager
#
#       Years of Experience    Salary
# 1225                 19.0  200000.0
# 1236                 20.0  200000.0
# 1258                 19.0  200000.0
# 1304                 20.0  200000.0
# 1305                 19.0  200000.0

# %%
min_edad = df["Age"].min()
print(min_edad)
# Out:
# 21.0

# %%
df[df["Age"]==21]
# Out:
#        Age  Gender Education Level                    Job Title  \
# 4884  21.0  Female     High School  Junior Sales Representative
# 4897  21.0  Female     High School  Junior Sales Representative
# 4910  21.0  Female     High School  Junior Sales Representative
# 4923  21.0  Female     High School  Junior Sales Representative
# 4936  21.0  Female     High School  Junior Sales Representative
# 4949  21.0  Female     High School  Junior Sales Representative
# 4962  21.0  Female     High School  Junior Sales Representative
# 4975  21.0  Female     High School  Junior Sales Representative
# 4988  21.0  Female     High School  Junior Sales Representative
# 5018  21.0  Female     High School  Junior Sales Representative
# 5031  21.0  Female     High School  Junior Sales Representative
# 5044  21.0  Female     High School  Junior Sales Representative
# 5057  21.0  Female     High School  Junior Sales Representative
# 5070  21.0  Female     High School  Junior Sales Representative
# ...

# %%
plt.scatter(df["Salary"],df["Age"])
plt.ylabel("Edad")
plt.xlabel("Salario")
# Out:
# Text(0.5, 0, 'Salario')

# %% [markdown]
# ### Género

# %%
female = df[df["Gender"]=="Female"]

# %%
female_media_edad = female["Age"].mean()
print(female_media_edad)
# Out:
# 32.62408759124087

# %%
female_mediana_edad = female["Age"].median()
print(female_mediana_edad)
# Out:
# 31.0

# %%
female_media_salario = female["Salary"].mean()
print(female_media_salario)
# Out:
# 107888.99867241952

# %%
plt.scatter(female["Salary"],female["Years of Experience"])
plt.title("Mujeres")
plt.ylabel("Años de experiencia")
plt.xlabel("Salario")
# Out:
# Text(0.5, 0, 'Salario')

# %%
male = df[df["Gender"]=="Male"]

# %%
male_media_edad = male["Age"].mean()
print(male_media_edad)
# Out:
# 34.41589548176375

# %%
male_mediana_edad = male["Age"].median()
print(male_mediana_edad)
# Out:
# 32.0

# %%
male_media_salario = male["Salary"].mean()
print(male_media_salario)
# Out:
# 121389.87091503268

# %%
plt.scatter(male["Salary"],male["Years of Experience"])
plt.title("Hombres")
plt.ylabel("Años de experiencia")
plt.xlabel("Salario")
# Out:
# Text(0.5, 0, 'Salario')

# %% [markdown]
# ### Experiencia y salario

# %%
media_salario = df["Salary"].mean()
print(media_salario)
# Out:
# 115326.96477086132

# %%
mediana_salario = df["Salary"].median()
print(mediana_salario)
# Out:
# 115000.0

# %%
plt.hist(df["Salary"])
plt.title("Salario")
plt.show()

# %%
media_exp = df["Years of Experience"].mean()
print(media_exp)
# Out:
# 8.094687360095508

# %%
mediana_exp = df["Years of Experience"].median()
print(mediana_exp)
# Out:
# 7.0

# %%
plt.hist(df["Years of Experience"])
plt.title("Años de experiencia")
plt.show()

# %%
plt.scatter(df["Salary"],df["Years of Experience"])
plt.ylabel("Años de experiencia")
plt.xlabel("Salario")
# Out:
# Text(0.5, 0, 'Salario')

# %% [markdown]
# ### Escolaridad

# %%
df[df["Education Level"] == "High School"]
# Out:
#        Age  Gender Education Level                    Job Title  \
# 2378  53.0   Other     High School      Senior Project Engineer
# 2385  25.0   Other     High School          Full Stack Engineer
# 2395  30.0    Male     High School      Senior Project Engineer
# 2403  28.0    Male     High School           Back end Developer
# 2411  24.0  Female     High School      Senior Project Engineer
# ...    ...     ...             ...                          ...
# 6686  32.0    Male     High School  Junior Sales Representative
# 6689  26.0  Female     High School              Sales Associate
# 6694  27.0    Male     High School    Digital Marketing Manager
# 6700  32.0    Male     High School              Sales Associate
# 6703  26.0  Female     High School              Sales Executive
#
#       Years of Experience    Salary
# 2378                 31.0  166109.0
# 2385                  2.0   69032.0
# 2395                 11.0  103947.0
# 2403                  7.0   95845.0
# ...

# %%
df[df["Education Level"] == "Bachelor's"]
# Out:
#        Age  Gender Education Level              Job Title  \
# 0     32.0    Male      Bachelor's      Software Engineer
# 3     36.0  Female      Bachelor's        Sales Associate
# 5     29.0    Male      Bachelor's      Marketing Analyst
# 7     31.0    Male      Bachelor's          Sales Manager
# 8     26.0  Female      Bachelor's  Marketing Coordinator
# ...    ...     ...             ...                    ...
# 1195  29.0  Female      Bachelor's           Data Analyst
# 1196  32.0    Male      Bachelor's      Software Engineer
# 1198  34.0    Male      Bachelor's      Software Engineer
# 1199  25.0  Female      Bachelor's           Data Analyst
# 1200  30.0    Male      Bachelor's        Product Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 3                     7.0   60000.0
# 5                     2.0   55000.0
# 7                     4.0   80000.0
# 8                     1.0   45000.0
# ...                   ...       ...
# ...

# %%
df[df["Education Level"] == "Master's"]
# Out:
#        Age  Gender Education Level           Job Title  Years of Experience  \
# 1     28.0  Female        Master's        Data Analyst                  3.0
# 4     52.0    Male        Master's            Director                 20.0
# 6     42.0  Female        Master's     Product Manager                 12.0
# 10    29.0    Male        Master's  Software Developer                  3.0
# 13    40.0  Female        Master's     Project Manager                 14.0
# ...    ...     ...             ...                 ...                  ...
# 1182  33.0    Male        Master's      Data Scientist                 10.0
# 1185  30.0    Male        Master's   Software Engineer                  6.0
# 1190  28.0  Female        Master's      Data Scientist                  6.0
# 1194  31.0    Male        Master's      Data Scientist                  9.0
# 1197  28.0  Female        Master's      Data Scientist                  6.0
#
#         Salary
# 1      65000.0
# 4     200000.0
# ...

# %%
df[df["Education Level"] == "PhD"]
# Out:
#        Age  Gender Education Level                         Job Title  \
# 2     45.0    Male             PhD                    Senior Manager
# 9     38.0    Male             PhD                  Senior Scientist
# 17    39.0    Male             PhD                   Senior Engineer
# 28    43.0  Female             PhD                 Senior Consultant
# 34    46.0    Male             PhD                    Senior Manager
# ...    ...     ...             ...                               ...
# 6682  28.0    Male             PhD                 Marketing Manager
# 6685  49.0  Female             PhD  Senior Product Marketing Manager
# 6691  36.0  Female             PhD                 Marketing Manager
# 6696  28.0    Male             PhD              Sales Representative
# 6699  49.0  Female             PhD             Director of Marketing
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# 9                    10.0  110000.0
# ...
